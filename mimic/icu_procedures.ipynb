# %% [markdown]
# # Procedures in ICU

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#! UNCOMMENT BELOW IF USING ON COLAB
# Access data using Google BigQuery on Google Colab
# from google.colab import auth
# from google.cloud import bigquery
# auth.authenticate_user()

# Dataset paths
project_id = "composite-drive-359503"   #! CHANGEME
physionet_proj = "physionet-data"
mimic_core = f"{physionet_proj}.mimic_core"
mimic_hosp = f"{physionet_proj}.mimic_hosp"
mimic_icu = f"{physionet_proj}.mimic_icu"
mimic_derived = f"{physionet_proj}.mimic_derived"

# Read data from BigQuery into pandas dataframes.
def run_query(query, project_id=project_id):
    return pd.io.gbq.read_gbq(
        query,
        project_id=project_id,
        dialect='standard')

# %%
# SQL query template
ditems_categories_query = f"""
--sql
SELECT
    ditems.category AS category,
    count(ditems.category) AS n_occurrence
FROM
    {mimic_icu}.d_items AS ditems
WHERE
    ditems.category LIKE "1%"
    OR ditems.category LIKE "2%"
    OR ditems.category LIKE "3%"
    OR ditems.category LIKE "4%"
    OR ditems.category LIKE "5%"
    OR ditems.category LIKE "6%"
    OR ditems.category LIKE "7%"
    OR ditems.category LIKE "8%"
    OR ditems.category LIKE "9%"
    OR ditems.category LIKE "10%"
GROUP BY
    ditems.category
ORDER BY
    n_occurrence DESC
"""

# %%
run_query(ditems_categories_query)
# Out:
#                   category  n_occurrence
# 0             4-Procedures            40
# 1     3-Significant Events            23
# 2                5-Imaging            18
# 3               6-Cultures            11
# 4          7-Communication             8
# 5  1-Intubation/Extubation             6
# 6            2-Ventilation             2

# %%
# SQL query template
procedures_query = f"""
--sql
SELECT
    procedures.itemid AS itemid,
    ditems.label AS label,
    ditems.category AS category,
    count(*) AS n_occurrences
FROM
    {mimic_icu}.procedureevents AS procedures
    INNER JOIN {mimic_icu}.d_items AS ditems
        ON procedures.itemid = ditems.itemid
WHERE
    lower(ditems.category) LIKE "3%"
    OR lower(ditems.category) LIKE "4%"
GROUP BY
    itemid, label, category
ORDER BY
    n_occurrences DESC
"""

# %%
run_query(procedures_query)
# Out:
#     itemid                                              label  \
# 0   225469                                        OR Received
# 1   225470                                            OR Sent
# 2   225464                       Cardioversion/Defibrillation
# 3   225440                                        Fluoroscopy
# 4   225466                                     Cardiac Arrest
# 5   225443                                   Nuclear Medicine
# 6   225465                                         Chest Pain
# 7   225821  Unplanned Line/Catheter Removal (Patient Initi...
# 8   225820                                  C-Spine Clearance
# 9   229579                  Transfer Intercampus by Ambulance
# 10  229755                                  Trigger Initiated
# 11  227715                                      TLS Clearance
# 12  225406                               Transferred to Floor
# 13  225475                                 Respiratory Arrest
# 14  225819                                        Brain Death
# 15  225474                                               Fall
# 16  225467                                       Chest Opened
# 17  225476  Unplanned Line/Catheter Removal (Non-Patient i...
# 18  225472                                       Pneumothorax
# 19  229620                                Massive Transfusion
#
#                 category  n_occurrences
# 0   3-Significant Events          15580
# 1   3-Significant Events           6919
# 2   3-Significant Events           1446
# 3   3-Significant Events            754
# 4   3-Significant Events            599
# 5   3-Significant Events            481
# 6   3-Significant Events            347
# 7   3-Significant Events            220
# 8   3-Significant Events            203
# 9   3-Significant Events            175
# 10  3-Significant Events            151
# 11  3-Significant Events            123
# 12  3-Significant Events            113
# 13  3-Significant Events            100
# 14  3-Significant Events             90
# 15  3-Significant Events             67
# 16  3-Significant Events             66
# 17  3-Significant Events             45
# 18  3-Significant Events             27
# 19  3-Significant Events             24
